# %% [markdown]
# ## Downloading the repository

# %%
# !git clone https://github.com/alsombra/Mask_RCNN-TF2  # updated repository
# Out:
# fatal: destination path 'Mask_RCNN-TF2' already exists and is not an empty directory.

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd Mask_RCNN-TF2
# Out:
# /content/Mask_RCNN-TF2

# %%
pwd
# Out:
# '/content/Mask_RCNN-TF2'

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 2)) (1.10.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 3)) (8.4.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 4)) (0.29.33)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 5)) (3.7.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 6)) (0.19.3)
# Requirement already satisfied: tensorflow>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 7)) (2.11.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 8)) (4.6.0.66)
# Requirement already satisfied: h5py in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 9)) (3.1.0)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 10)) (0.4.0)
# Requirement already satisfied: IPython[all] in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 11)) (7.9.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r requirements.txt (line 5)) (4.39.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r requirements.txt (line 5)) (23.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r requirements.txt (line 5)) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r requirements.txt (line 5)) (1.0.7)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image->-r requirements.txt (line 6)) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image->-r requirements.txt (line 6)) (2023.2.28)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image->-r requirements.txt (line 6)) (1.4.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.9/dist-packages (from scikit-image->-r requirements.txt (line 6)) (3.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0.0->-r requirements.txt (line 7)) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0.0->-r requirements.txt (line 7)) (4.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0.0->-r requirements.txt (line 7)) (0.31.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0.0->-r requirements.txt (line 7)) (2.11.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0.0->-r requirements.txt (line 7)) (2.11.2)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0.0->-r requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0.0->-r requirements.txt (line 7)) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0.0->-r requirements.txt (line 7)) (1.51.3)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0.0->-r requirements.txt (line 7)) (1.15.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0.0->-r requirements.txt (line 7)) (1.15.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0.0->-r requirements.txt (line 7)) (23.3.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0.0->-r requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0.0->-r requirements.txt (line 7)) (3.3.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0.0->-r requirements.txt (line 7)) (15.0.6.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0.0->-r requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0.0->-r requirements.txt (line 7)) (3.19.6)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0.0->-r requirements.txt (line 7)) (2.11.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0.0->-r requirements.txt (line 7)) (63.4.3)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.9/dist-packages (from imgaug->-r requirements.txt (line 10)) (2.0.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from IPython[all]->-r requirements.txt (line 11)) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from IPython[all]->-r requirements.txt (line 11)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from IPython[all]->-r requirements.txt (line 11)) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from IPython[all]->-r requirements.txt (line 11)) (5.7.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from IPython[all]->-r requirements.txt (line 11)) (2.6.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from IPython[all]->-r requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.9/dist-packages (from IPython[all]->-r requirements.txt (line 11)) (0.18.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from IPython[all]->-r requirements.txt (line 11)) (2.0.10)
# Requirement already satisfied: nose>=0.10.1 in /usr/local/lib/python3.9/dist-packages (from IPython[all]->-r requirements.txt (line 11)) (1.3.7)
# Requirement already satisfied: Sphinx>=1.3 in /usr/local/lib/python3.9/dist-packages (from IPython[all]->-r requirements.txt (line 11)) (3.5.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from IPython[all]->-r requirements.txt (line 11)) (2.25.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from IPython[all]->-r requirements.txt (line 11)) (5.7.3)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.9/dist-packages (from IPython[all]->-r requirements.txt (line 11)) (5.4.1)
# Requirement already satisfied: ipyparallel in /usr/local/lib/python3.9/dist-packages (from IPython[all]->-r requirements.txt (line 11)) (8.4.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.9/dist-packages (from IPython[all]->-r requirements.txt (line 11)) (0.6.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from IPython[all]->-r requirements.txt (line 11)) (6.5.4)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.9/dist-packages (from IPython[all]->-r requirements.txt (line 11)) (7.7.1)
# Requirement already satisfied: notebook in /usr/local/lib/python3.9/dist-packages (from IPython[all]->-r requirements.txt (line 11)) (6.3.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.9/dist-packages (from IPython[all]->-r requirements.txt (line 11)) (5.3.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow>=2.0.0->-r requirements.txt (line 7)) (0.40.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->-r requirements.txt (line 5)) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->IPython[all]->-r requirements.txt (line 11)) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython[all]->-r requirements.txt (line 11)) (0.2.6)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.9/dist-packages (from Sphinx>=1.3->IPython[all]->-r requirements.txt (line 11)) (2.2.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.9/dist-packages (from Sphinx>=1.3->IPython[all]->-r requirements.txt (line 11)) (1.0.2)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.9/dist-packages (from Sphinx>=1.3->IPython[all]->-r requirements.txt (line 11)) (1.1.5)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.9/dist-packages (from Sphinx>=1.3->IPython[all]->-r requirements.txt (line 11)) (2.12.1)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.9/dist-packages (from Sphinx>=1.3->IPython[all]->-r requirements.txt (line 11)) (1.0.3)
# Requirement already satisfied: docutils<0.17,>=0.12 in /usr/local/lib/python3.9/dist-packages (from Sphinx>=1.3->IPython[all]->-r requirements.txt (line 11)) (0.16)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.9/dist-packages (from Sphinx>=1.3->IPython[all]->-r requirements.txt (line 11)) (1.0.4)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.9/dist-packages (from Sphinx>=1.3->IPython[all]->-r requirements.txt (line 11)) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /usr/local/lib/python3.9/dist-packages (from Sphinx>=1.3->IPython[all]->-r requirements.txt (line 11)) (2.0.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.9/dist-packages (from Sphinx>=1.3->IPython[all]->-r requirements.txt (line 11)) (0.7.13)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.9/dist-packages (from Sphinx>=1.3->IPython[all]->-r requirements.txt (line 11)) (3.1.2)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.9/dist-packages (from Sphinx>=1.3->IPython[all]->-r requirements.txt (line 11)) (1.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->IPython[all]->-r requirements.txt (line 11)) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->IPython[all]->-r requirements.txt (line 11)) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->IPython[all]->-r requirements.txt (line 11)) (1.26.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->IPython[all]->-r requirements.txt (line 11)) (2.10)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0.0->-r requirements.txt (line 7)) (2.2.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0.0->-r requirements.txt (line 7)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0.0->-r requirements.txt (line 7)) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0.0->-r requirements.txt (line 7)) (2.16.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0.0->-r requirements.txt (line 7)) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0.0->-r requirements.txt (line 7)) (0.4.6)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel->IPython[all]->-r requirements.txt (line 11)) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel->IPython[all]->-r requirements.txt (line 11)) (6.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from ipyparallel->IPython[all]->-r requirements.txt (line 11)) (5.4.8)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from ipyparallel->IPython[all]->-r requirements.txt (line 11)) (0.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from ipyparallel->IPython[all]->-r requirements.txt (line 11)) (4.65.0)
# Requirement already satisfied: pyzmq>=18 in /usr/local/lib/python3.9/dist-packages (from ipyparallel->IPython[all]->-r requirements.txt (line 11)) (23.2.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->IPython[all]->-r requirements.txt (line 11)) (3.6.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->IPython[all]->-r requirements.txt (line 11)) (3.0.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->IPython[all]->-r requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->IPython[all]->-r requirements.txt (line 11)) (0.2.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->IPython[all]->-r requirements.txt (line 11)) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->IPython[all]->-r requirements.txt (line 11)) (1.2.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->IPython[all]->-r requirements.txt (line 11)) (4.9.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->IPython[all]->-r requirements.txt (line 11)) (6.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->IPython[all]->-r requirements.txt (line 11)) (2.1.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->IPython[all]->-r requirements.txt (line 11)) (4.9.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->IPython[all]->-r requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->IPython[all]->-r requirements.txt (line 11)) (0.8.4)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.9/dist-packages (from nbconvert->IPython[all]->-r requirements.txt (line 11)) (5.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->IPython[all]->-r requirements.txt (line 11)) (0.7.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->IPython[all]->-r requirements.txt (line 11)) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->IPython[all]->-r requirements.txt (line 11)) (4.3.3)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook->IPython[all]->-r requirements.txt (line 11)) (0.16.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from notebook->IPython[all]->-r requirements.txt (line 11)) (1.8.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook->IPython[all]->-r requirements.txt (line 11)) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook->IPython[all]->-r requirements.txt (line 11)) (0.17.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->IPython[all]->-r requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: qtpy>=2.0.1 in /usr/local/lib/python3.9/dist-packages (from qtconsole->IPython[all]->-r requirements.txt (line 11)) (2.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0.0->-r requirements.txt (line 7)) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0.0->-r requirements.txt (line 7)) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0.0->-r requirements.txt (line 7)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow>=2.0.0->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->IPython[all]->-r requirements.txt (line 11)) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->IPython[all]->-r requirements.txt (line 11)) (22.2.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.7->nbconvert->IPython[all]->-r requirements.txt (line 11)) (3.1.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow>=2.0.0->-r requirements.txt (line 7)) (6.0.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook->IPython[all]->-r requirements.txt (line 11)) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert->IPython[all]->-r requirements.txt (line 11)) (2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->IPython[all]->-r requirements.txt (line 11)) (0.5.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0.0->-r requirements.txt (line 7)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow>=2.0.0->-r requirements.txt (line 7)) (3.2.2)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->IPython[all]->-r requirements.txt (line 11)) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->IPython[all]->-r requirements.txt (line 11)) (2.21)

# %%
# !python setup.py install# all information about the model to access mrcnn
# Out:
# WARNING:root:Fail load requirements file, so using default ones.
# /usr/local/lib/python3.9/dist-packages/setuptools/dist.py:771: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/dist.py:771: UserWarning: Usage of dash-separated 'license-file' will not be supported in future versions. Please use the underscore name 'license_file' instead
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/dist.py:771: UserWarning: Usage of dash-separated 'requirements-file' will not be supported in future versions. Please use the underscore name 'requirements_file' instead
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/config/setupcfg.py:508: SetuptoolsDeprecationWarning: The license_file parameter is deprecated, use license_files instead.
#   warnings.warn(msg, warning_class)
# invalid command name 'install#'

# %%
# %cd ..
# Out:
# /content

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# ## Importing the libraries

# %%
# %%capture
pip install pixellib

# %%
import os   # to access operational system features
import sys   # to access information regards to system
import cv2   # python library to work with images
import numpy as np # to work with vectors and metrices
import skimage.io   # python library to work with images
from google.colab.patches import cv2_imshow  # to show the images with cv2
import matplotlib.pyplot as plt  # to generate graphs or to show images
import pixellib
from pixellib.instance import instance_segmentation

# %%
# %tensorflow_version 1.x  # run this if your tensor version is 2.x
import tensorflow as tf  # to import tensorflow

# %%
tf.__version__   # to check out the version
# Out:
# '2.11.0'

# %%
ROOT_DIR = os.path.abspath('./Mask_RCNN-TF2')
ROOT_DIR
# Out:
# '/content/Mask_RCNN-TF2'

# %%
sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python39.zip',
#  '/usr/lib/python3.9',
#  '/usr/lib/python3.9/lib-dynload',
#  '',
#  '/usr/local/lib/python3.9/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.9/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/Mask_RCNN-TF2',
#  '/',
#  '/content/Mask_RCNN-TF2/samples/coco/',
#  '/']

# %%
sys.path.append(ROOT_DIR)  # to add all of this files in ( ROOT_DIR) to your system path

# %%
sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python39.zip',
#  '/usr/lib/python3.9',
#  '/usr/lib/python3.9/lib-dynload',
#  '',
#  '/usr/local/lib/python3.9/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.9/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/Mask_RCNN-TF2',
#  '/',
#  '/content/Mask_RCNN-TF2/samples/coco/',
#  '/',
#  '/content/Mask_RCNN-TF2']

# %%
from mrcnn import utils  # to import the ( utils file) from (mrcnn) directory
from mrcnn import visualize  # to import the ( utils file) from (mrcnn) directory
import mrcnn.model as modellib  # to import the ( model file) from (mrcnn) directory

# %%
# https://cocodataset.org/#home
sys.path.append(os.path.join(ROOT_DIR, 'samples/coco/'))  # to add the COCO Datasets to system and it can classify 80 objects ( the join are going to concatenate the both directories)

# %%
sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python39.zip',
#  '/usr/lib/python3.9',
#  '/usr/lib/python3.9/lib-dynload',
#  '',
#  '/usr/local/lib/python3.9/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.9/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/Mask_RCNN-TF2',
#  '/',
#  '/content/Mask_RCNN-TF2/samples/coco/',
#  '/',
#  '/content/Mask_RCNN-TF2',
#  '/content/Mask_RCNN-TF2/samples/coco/']

# %%
import coco

# %%
MODEL_DIR = os.path.join(ROOT_DIR, 'logs') # to concatenate the ( root dir ) with (logs)
IMAGE_DIR = os.path.join(ROOT_DIR, 'images')  # to concatenate the root dir with ( images ) and you can check the image directory NOW

# %%
MODEL_DIR, IMAGE_DIR  # to print the location of both variables
# Out:
# ('/content/Mask_RCNN-TF2/logs', '/content/Mask_RCNN-TF2/images')

# %% [markdown]
# ### [ ! ] Compatibility Update
# Run the 5 lines below so we don't have any issues when running with the latest versions of Tensorflow

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
# Out:
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/client/session.py:1769: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '

# %% [markdown]
# ## Loading the pre-trained neural network

# %%
COCO_MODEL_PATH = os.path.join(ROOT_DIR, 'mask_rcnn_coco.h5')  # h5 is a file contained a trained neural network with tensorflow

# %%
utils.download_trained_weights(COCO_MODEL_PATH)  # to download the pre-trained model
# Out:
# Downloading pretrained model to /content/Mask_RCNN-TF2/mask_rcnn_coco.h5 ...
# ... done downloading pretrained model!

# %%
class InferenceConfig(coco.CocoConfig):  # check the GPU ACTIVATION
  GPU_COUNT = 1
  IMAGES_PER_GPU = 1  # similar to batch size ( like 10 images and update , and so on)

# %%
config = InferenceConfig()

# %%
config.display()  # all the information about the neural network
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                93
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           coco
# NUM_CLASSES                    81
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
MODEL_DIR
# Out:
# '/content/Mask_RCNN-TF2/logs'

# %%
network = modellib.MaskRCNN(mode='inference', model_dir=MODEL_DIR, config=config)  # inference means we are not going to train the model but we just goin to get the predictions

# %%
network.load_weights(COCO_MODEL_PATH, by_name=True)  # to load the weights from COCO

# %% [markdown]
# ## Detecting objects

# %%
class_names = ['BG', 'person', 'bicycle', 'car', 'motorcycle', 'airplane',
               'bus', 'train', 'truck', 'boat', 'traffic light',
               'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird',
               'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear',
               'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie',
               'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
               'kite', 'baseball bat', 'baseball glove', 'skateboard',
               'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup',
               'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple',
               'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
               'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed',
               'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote',
               'keyboard', 'cell phone', 'microwave', 'oven', 'toaster',
               'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors',
               'teddy bear', 'hair drier', 'toothbrush']

# %%
len(class_names)  # to print the number of objects that COCO can detect
# Out:
# 81

# %%
class_names[3]
# Out:
# 'car'

# %%
class_names[1], class_names.index('person')
# Out:
# ('person', 1)

# %%
segment_video = instance_segmentation()
segment_video.load_model("/content/Mask_RCNN-TF2/mask_rcnn_coco.h5")
segment_video.process_video("/content/british_highway_traffic.mp4", show_bboxes = True, frames_per_second= 15, output_video_name="british_highway_traffic_out.mp4")
# Out:
# No. of frames: 1
# No. of frames: 2
# No. of frames: 3
# No. of frames: 4
# No. of frames: 5
# No. of frames: 6
# No. of frames: 7
# No. of frames: 8
# No. of frames: 9
# No. of frames: 10
# No. of frames: 11
# No. of frames: 12
# No. of frames: 13
# No. of frames: 14
# No. of frames: 15
# No. of frames: 16
# No. of frames: 17
# No. of frames: 18
# No. of frames: 19
# No. of frames: 20
# No. of frames: 21
# No. of frames: 22
# No. of frames: 23
# No. of frames: 24
# No. of frames: 25
# No. of frames: 26
# No. of frames: 27
# No. of frames: 28
# No. of frames: 29
# No. of frames: 30
# No. of frames: 31
# No. of frames: 32
# No. of frames: 33
# No. of frames: 34
# No. of frames: 35
# No. of frames: 36
# No. of frames: 37
# No. of frames: 38
# No. of frames: 39
# No. of frames: 40
# No. of frames: 41
# No. of frames: 42
# No. of frames: 43
# No. of frames: 44
# No. of frames: 45
# No. of frames: 46
# No. of frames: 47
# No. of frames: 48
# No. of frames: 49
# No. of frames: 50
# No. of frames: 51
# No. of frames: 52
# No. of frames: 53
# No. of frames: 54
# No. of frames: 55
# No. of frames: 56
# No. of frames: 57
# No. of frames: 58
# No. of frames: 59
# No. of frames: 60
# No. of frames: 61
# No. of frames: 62
# No. of frames: 63
# No. of frames: 64
# No. of frames: 65
# No. of frames: 1503
# No. of frames: 1504
# No. of frames: 1505
# No. of frames: 1506
# No. of frames: 1507
# No. of frames: 1508
# No. of frames: 1509
# No. of frames: 1510
# No. of frames: 1511
# No. of frames: 1512
# No. of frames: 1513
# No. of frames: 1514
# No. of frames: 1515
# No. of frames: 1516
# No. of frames: 1517
# No. of frames: 1518
# No. of frames: 1519
# No. of frames: 1520
# No. of frames: 1521
# No. of frames: 1522
# No. of frames: 1523
# No. of frames: 1524
# No. of frames: 1525
# No. of frames: 1526
# No. of frames: 1527
# No. of frames: 1528
# No. of frames: 1529
# No. of frames: 1530
# No. of frames: 1531
# No. of frames: 1532
# No. of frames: 1533
# No. of frames: 1534
# No. of frames: 1535
# No. of frames: 1536
# No. of frames: 1537
# No. of frames: 1538
# No. of frames: 1539
# No. of frames: 1540
# No. of frames: 1541
# No. of frames: 1542
# No. of frames: 1543
# No. of frames: 1544
# No. of frames: 1545
# No. of frames: 1546
# No. of frames: 1547
# No. of frames: 1548
# No. of frames: 1549
# Processed 1550 frames in 1130.4 seconds
# ({'rois': array([[ 339,  320,  447,  440],
#          [ 128,  850,  174,  909],
#          [ 179, 1068,  235, 1137],
#          [  88,  866,  137,  930],
#          [ 349,   34,  475,  172],
#          [  44,  953,   85, 1008],
#          [ 386,    0,  431,   40],
#          [   0,  918,   24,  969],
#          [   0, 1030,   19, 1053],
#          [   2,  998,   26, 1049],
#          [ 266, 1113,  330, 1195]], dtype=int32),
#   'class_ids': array([ 8,  3,  3,  3,  8,  3, 14,  3,  3,  3,  3], dtype=int32),
#   'scores': array([0.99945813, 0.99322444, 0.9872333 , 0.97529805, 0.96484375,
#          0.9247644 , 0.80740625, 0.7588558 , 0.75169754, 0.7428963 ,
#          0.705759  ], dtype=float32),
#   'masks': array([[[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          ...,
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]]])},
#  array([[[ 40,  89,  77],
#          [ 40,  89,  77],
#          [ 40,  89,  77],
#          ...,
#          [ 28,  68,  57],
#          [ 25,  67,  56],
#          [ 24,  66,  55]],
#
#         [[ 39,  88,  76],
#          [ 39,  88,  76],
#          [ 39,  88,  76],
#          ...,
#          [ 24,  64,  53],
#          [ 20,  62,  51],
#          [ 19,  61,  50]],
#
#         [[ 37,  86,  74],
#          [ 37,  86,  74],
#          [ 38,  87,  75],
#          ...,
#          [ 22,  62,  51],
#          [ 19,  61,  50],
#          [ 18,  60,  49]],
#
#         ...,
#
#         [[ 71, 138, 126],
#          [ 71, 138, 126],
#          [ 72, 139, 127],
#          ...,
#          [ 15,  30,  19],
#          [ 15,  30,  19],
#          [ 15,  30,  19]],
#
#         [[105, 132, 126],
#          [105, 132, 126],
#          [105, 132, 126],
#          ...,
#          [ 16,  31,  20],
#          [ 16,  31,  20],
#          [ 16,  31,  20]],
#
#         [[  0,   7,   1],
#          [  0,   7,   1],
#          [  0,   8,   2],
#          ...,
#          [  0,   6,   0],
#          [  0,   6,   0],
#          [  0,   6,   0]]], dtype=uint8))
